# %%
import pickle
import numpy as np

# %%
pipe=pickle.load(open('model/pipe.pkl','rb'))

# %%
test=np.array([3,'female',22.0,1,1,12.0,'S'],dtype=object).reshape(1,7)

# %%
pipe.predict(test)
# Out:
# d:\machine learning\venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# d:\machine learning\venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])
