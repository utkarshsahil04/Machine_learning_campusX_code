# %%
import pandas as pd

# %%
df=pd.read_csv("esports_leads.csv")

# %%
df
# Out:
#                   Name                                                Bio  \
# 0         Nirvan Pawar  Founder & Leading Brand Partnerships at Badkin...
# 1        Karan Kharwar  Building Esports Ecosystems | CEO @ UGOD Espor...
# 2         Pranav Nande  CEO | Esports Organization | Tournaments • Tea...
# 3          Keshav Goel             Student at Newton School of Technology
# 4       Sreyan Patnaik  Talent & Social Media Manager | Strategic Bran...
# ..                 ...                                                ...
# 192  Hardik Gurudasani  Looking for oRTB | VAST | XML | Direct Partner...
# 193     SHASHANK PATEL  Accounts & Partnership Manager | Mobile Growth...
# 194       Pari Guliani  Sponsorship and Partnership Associate at World...
# 195     Rajesh Garhwal  📊 Professional Trader Looking for Capital Part...
# 196          Jayeta R.                          Brand Partnership Manager
#
#                                               Location  \
# ...

# %%
# check duplicates
# print(df.duplicated("Name").sum())
if df.duplicated("Name").sum()==0:
    print("Np dublication")
# Out:
# Np dublication
