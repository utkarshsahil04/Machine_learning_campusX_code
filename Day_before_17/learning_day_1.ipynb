# %%
import pandas as pd 
import numpy as np 
from sklearn.preprocessing import LabelEncoder,StandardScaler,minmax_scale
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.metrics import accuracy_score,recall_score
df=pd.read_csv("IRIS.csv")
le=LabelEncoder()
df_copy=df.copy()
df_copy["species_encoded"]=le.fit_transform(df_copy["species"])
df_dummies=pd.get_dummies(df_copy,columns=["species_encoded"])
# print(df_copy.head())
print(df_dummies)
# x=df_copy[["sepal_length","sepal_width","petal_length","petal_width"]]
# y=df_copy["species_encoded"]
# print(y)
# X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.1,random_state=7)
# model=LogisticRegression(max_iter=200)
# model.fit(X_train,Y_train)
# y_predict=model.predict(X_test)
# # accuracy=accuracy_score(Y_test,y_predict)
# cross_score=cross_val_score(model,x,y,cv=5)
# print("Cross selction socre",cross_score)
# print("avaerage score:", cross_score.mean())
# print(accuracy)
# print(df_copy[40:60])
# print(df_copy)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#      species_encoded_0  species_encoded_1  species_encoded_2
# ...
